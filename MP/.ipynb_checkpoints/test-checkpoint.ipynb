# %%
# %matplotlib inline

import glob
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

from matrixprofile import *
from scipy.stats import zscore

# %% [markdown]
# Matrix Profileが最小値を取るペアを発見する

# %%
def find_minimum_pair(MatP, MatPind):
    minpair = np.unique(np.union1d(np.where(MatP == MatP.min()), MatPind[np.where(MatP == MatP.min())]))
    minpair = minpair.astype('int')
    return minpair

# %% [markdown]
# ## 人工データ

# %%
trace = np.asarray(pd.read_csv('../Datasets/UCR_TS_Archive_2015/Trace/Trace_TRAIN'))
t = np.concatenate((trace[2][100:200],trace[12][100:300]))
plt.plot(t)
plt.show()
mpt, mptindex = matrixProfile.stomp(t,30)
plt.plot(mpt)
plt.show()

# %%
si = np.sin(np.linspace(0,4*np.pi,60))
plt.plot(si)

# %%
m = 30 #distance profileのクエリの長さ
disP = []
for i in range(len(si)-m+1):
    disP.append(matrixProfile.distanceProfile.massDistanceProfile(si,i,m,t)[0])
disP = np.asarray(disP)

# %%
plt.plot(disP[16].T)
plt.show()

# %%
plt.plot(disP)

# %% [markdown]
# ## 線虫

# %%
m = 60 # MatrixProfileの部分時系列の長さ
topN = 7000 # 線虫の頭何個使うか

# %% [markdown]
# データ呼び出し

# %%
filenames1 = glob.glob("../Datasets/worm1/*f4")
filenames1.sort()
np.random.seed(0)
a = np.fromfile(filenames1[53],'f4')[:topN] - 10e-4*np.random.randn(topN)
a_nonoise = np.fromfile(filenames1[53],'f4')[:topN]
plt.plot(a)
plt.show()

# %%
# a[3300:3500] += 30 * np.sin(np.linspace(0,2*np.pi,200))
# a[4500:4700] += 30 * np.sin(np.linspace(0,2*np.pi,200))
# a[5300:5500] += 30 * np.sin(np.linspace(0,2*np.pi,200))

# %%
MP, MPind = matrixProfile.stomp(a,m)
MPind = MPind.astype('int')

# %% [markdown]
# 0の数に対するAV

# %%
AV_zero = np.zeros_like(MP)

for i,_ in enumerate(AV_zero):
    AV_zero[i] = np.sum(a_nonoise[i:i+m]==0)

AV_zero -= min(AV_zero)
AV_zero /= max(AV_zero)

AV_zero = 1 - AV_zero

MP_zero = MP + (1-AV_zero) * MP.max()

plt.subplot(2,1,1)
plt.plot(MP)
plt.title("original")

plt.subplot(2,1,2)
plt.plot(MP_zero)
plt.title("Annotated")

plt.tight_layout()
plt.show()

# %% [markdown]
# 複雑さに対する　AV

# %%
plt.plot(a[0:30])

# %%
AV_comp = np.zeros_like(MP)

for i,_ in enumerate(AV_comp):
    AV_comp[i] = np.sqrt(np.sum(np.diff(zscore(a[i:i+m]))**2))
    
AV_comp -= min(AV_comp)
AV_comp /= max(AV_comp)

MP_comp = MP + (1-AV_comp) * MP.max()

plt.subplot(2,1,1)
plt.plot(MP)
plt.title("original")

plt.subplot(2,1,2)
plt.plot(MP_comp)
plt.title("Annotated")

plt.tight_layout()
plt.show()

# %% [markdown]
# 合成

# %%
AV_sum = AV_zero + AV_comp
AV_sum -= min(AV_sum)
AV_sum /= max(AV_sum)

MP_sum = MP + (1-AV_sum) * MP.max()

plt.subplot(2,1,1)
plt.plot(MP)
plt.title("original")

plt.subplot(2,1,2)
plt.plot(MP_sum)
plt.title("Annotated")

plt.tight_layout()
plt.show()

# %%
plt.plot(a)

# %%
find_minimum_pair(MP_sum,MPind)
plt.plot(zscore(a[mindex[0]:mindex[0]+m]))
plt.plot(zscore(a[mindex[1]:mindex[1]+m]))
plt.show()

# %%
find_minimum_pair(MP_comp,MPind)
plt.plot(zscore(a[mindex[0]:mindex[0]+m]))
plt.plot(zscore(a[mindex[1]:mindex[1]+m]))
plt.show()

# %%
find_minimum_pair(MP,MPind)
plt.plot(zscore(a[mindex[0]:mindex[0]+m]))
plt.plot(zscore(a[mindex[1]:mindex[1]+m]))
plt.show()

# %%
plt.plot(MP)
plt.show()

# %%
mindex = find_minimum_pair(MP_sum,MPind)
plt.plot(zscore(a[mindex[0]:mindex[0]+m]))
plt.plot(zscore(a[mindex[1]:mindex[1]+m]))
plt.show()

# %%
plt.plot((a[mindex[0]-50:mindex[0]+m+50]))
# plt.plot((a[mindex[1]:mindex[1]+m]))

# %%
mindex = find_minimum_pair(MP_zero, MPind)
plt.plot(zscore(a[mindex[0]:mindex[0]+m]))
plt.plot(zscore(a[mindex[1]:mindex[1]+m]))
plt.show()

# %%
a[mindex[0]:mindex[0]+m]
# Out:
# array([47.00109692, 47.00092736, 46.99911166, 47.00052474, 47.00138528,
#        46.99989782, 46.99949501, 46.99867104, 46.9997821 , 47.00065971,
#        46.99952599, 46.99927283, 47.00003891, 47.0000446 , 46.99973987,
#        47.00006986, 46.99974989, 47.00102191, 47.00115044, 39.00083611,
#        38.99935779, 38.9997412 , 38.99895976, 39.00018669, 39.00114364,
#        38.99885545, 39.00001877, 38.99871654, 38.99940205, 38.99781138,
#        39.00021977, 38.99909928, 38.99910864, 39.00055513, 39.00017248,
#        39.00146174, 39.0015488 , 38.99987343, 38.99920699, 38.99936198,
#        38.99965998, 38.99913698, 39.0005897 , 39.00027253, 38.99926248,
#        38.99956688, 39.00021019, 38.99867921, 39.001292  , 39.00051868,
#        39.0002834 , 38.99918347, 38.99999761, 39.00126149, 38.999486  ,
#        38.99891245, 38.9992607 , 38.99938085, 39.00187431, 39.00089989])

# %%
focus = np.array([502,795,2729,4753])
focus_pair = MPind[focus]
for i, (f, fp) in enumerate(zip(focus,focus_pair)):
    plt.subplot(2,2,i+1)
    plt.plot(zscore(a[f:f+m]))
    plt.plot(zscore(a[fp:fp+m]))
plt.show()


print('f  = ', focus)
print('fp = ', focus_pair)
print('dist = ', MP[focus])
# Out:
# f  =  [ 502  795 2729 4753]
# fp =  [ 794  590 5707 4881]
# dist =  [4.16498238 3.37163608 4.14354444 3.79507273]

# %%
mindex = find_minimum_pair(MP,MPind)

# %%
mindex
# Out:
# array([2736, 4888])

# %%
np.linalg.norm(zscore(a[mindex[0]:mindex[0]+m]) - zscore(a[mindex[1]:mindex[1]+m]))
# Out:
# 2.5461354224318846

# %%
plt.plot(zscore(a[mindex[0]:mindex[0]+m]))
plt.plot(zscore(a[mindex[1]:mindex[1]+m]))
plt.show()

# %%
plt.plot(a[3059:3259])

# %%
plt.plot(AV_comp[3059:3259])
plt.show()

# %%
plt.plot(MP)
plt.show()

# %%
plt.plot(a[2483:2683])
